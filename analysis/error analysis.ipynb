# %%
import pandas as pd
pd.options.display.max_colwidth = 1000

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('..')

from word2morph import Word2Morph
from word2morph.data.loaders import DataLoader

# %%
word2morph = Word2Morph.load_model(path='../logs/best-model.joblib')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
train = DataLoader(file_path='../datasets/rus.train').load()
valid = DataLoader(file_path='../datasets/rus.valid').load()
test = DataLoader(file_path='../datasets/rus.test').load()

# %%
correct, wrong, predicted_samples = word2morph.evaluate(test, batch_size=1)
# Out:
# Evaluating for epoch 1...
# {'test_acc': 0.9600512546889147,
#  'test_acc_processed': 0.9600189173457508,
#  'test_auc': 0.9743393176163997,
#  'test_auc_processed': 0.9743105503871001,
#  'test_f1': 0.9546705079727551,
#  'test_f1_processed': 0.9546313196763908,
#  'test_loss': 1.3797807815568301,
#  'test_loss_processed': 1.380897673821573,
#  'test_precision': 0.9597629994764508,
#  'test_precision_processed': 0.9597406706562298,
#  'test_recall': 0.9509018964213974,
#  'test_recall_processed': 0.9508460589716579,
#  'test_word_acc': 0.8689821755788772,
#  'test_word_acc_processed': 0.8689821755788772}
# Sample accuracy: 0.8689821755788772

# %%
len(correct), len(wrong), len(predicted_samples)
# Out:
# (20866, 3146, 24012)

# %% [markdown]
# ## Wrong predictions

# %%
# pred, correct
str(wrong[0][0]), str(wrong[0][1])
# Out:
# ('лядунка\tляд:ROOT/унк:SUFF/а:END', 'лядунка\tлядун:ROOT/к:SUFF/а:END')

# %%
df = pd.DataFrame(data=[(str(pred).split('\t')[0], str(pred).split('\t')[-1], 
                         str(cor).split('\t')[-1]) for pred, cor in wrong], 
                  columns=['Word', 'Predicted segments', 'Correct segments'])
df.head(n=50)
# Out:
#                      Word  \
# 0                 лядунка
# 1                    жила
# 2           выдыхательный
# 3              кокаиновый
# 4   радиально-сверлильный
# 5                  рубчик
# 6               ороговеть
# 7                 сотенка
# 8              колоратура
# 9          подтвержденный
# 10                тирания
# 11                  прель
# 12           двуличничать
# 13               соопекун
# 14         тезоименитство
# 15          чаезавялочный
# 16            автореферат
# 17              гибельный
# 18             намеренный
# 19              дворцовый
# 20                бегунок
# 21                 некого
# 22              комбикорм
# 23            контрибуция
# 24               ботвинья
# 25             совместный
# 26      остросатирический
# 27        полунезависимый
# 28               полемика
# 29                 плотик
# 30           столкновение
# 31               пешочком
# 32             амилнитрит
# 33                 крекер
# 34             полотняный
# 35                 подина
# 36               небосвод
# 37          концентричный
# 38             разнотолки
# 39                 квелый
# 40               баростат
# 41                 камбий
# 42             кордебалет
# 43                обычный
# 44               женьшень
# 45         автоподстройка
# 46                  вздох
# 47            заслуживать
# 48           постоянность
# 49                сотняга
#
#                                                                  Predicted segments  \
# 0                                                           ляд:ROOT/унк:SUFF/а:END
# 1                                                              жи:ROOT/л:SUFF/а:END
# 2                                   вы:PREF/дых:ROOT/а:SUFF/тель:SUFF/н:SUFF/ый:END
# 3                                                  кока:ROOT/ин:SUFF/ов:SUFF/ый:END
# 4   рад:ROOT/и:SUFF/альн:SUFF/о:LINK/-:HYPH/сверл:ROOT/и:SUFF/ль:SUFF/н:SUFF/ый:END
# 5                                                                 руб:ROOT/чик:SUFF
# 6                                                  орог:ROOT/ов:SUFF/е:SUFF/ть:SUFF
# 7                                                           сот:ROOT/енк:ROOT/а:END
# 8                                                  колор:ROOT/ат:SUFF/ур:SUFF/а:END
# 9                                              под:PREF/твержд:ROOT/енн:SUFF/ый:END
# 10                                                                тирани:ROOT/я:END
# 11                                                                       прель:ROOT
# 12                                  дв:ROOT/у:PREF/лич:ROOT/нич:SUFF/а:SUFF/ть:SUFF
# 13                                                              соопек:ROOT/ун:SUFF
# 14                           тез:ROOT/о:SUFF/и:SUFF/мен:ROOT/ит:SUFF/ств:SUFF/о:END
# 15                            ча:ROOT/е:LINK/за:PREF/вял:ROOT/оч:SUFF/н:SUFF/ый:END
# 16                                                     авто:ROOT/рефер:ROOT/ат:SUFF
# 17                                                        гибель:ROOT/н:SUFF/ый:END
# 18                                                 на:PREF/мер:ROOT/енн:SUFF/ый:END
# 19                                                  двор:ROOT/ц:SUFF/ов:SUFF/ый:END
# 20                                                               бег:ROOT/унок:SUFF
# 21                                                           не:PREF/ког:ROOT/о:END
# 22                                                       ком:ROOT/би:PREF/корм:ROOT
# 23                                                      контрибуц:ROOT/и:SUFF/я:END
# 24                                                         бот:ROOT/винь:ROOT/я:END
# 25                                                       совмест:ROOT/н:SUFF/ый:END
# 26                                                остросатир:ROOT/ическ:SUFF/ий:END
# 27                                      пол:ROOT/у:PREF/независ:ROOT/им:SUFF/ый:END
# 28                                                               полемик:ROOT/а:END
# 29                                                                      плотик:ROOT
# 30                             с:PREF/толк:ROOT/н:SUFF/о:LINK/ве:ROOT/ни:SUFF/е:END
# 31                                                              пешоч:ROOT/ком:SUFF
# 32                                                а:PREF/мил:ROOT/нитр:ROOT/ит:SUFF
# 33                                                                крек:ROOT/ер:SUFF
# 34                                           пол:ROOT/от:SUFF/н:SUFF/ян:SUFF/ый:END
# 35                                                                 подин:ROOT/а:END
# 36                                                              не:PREF/босвод:ROOT
# 37                                                    концентр:ROOT/ичн:SUFF/ый:END
# 38                                           разн:ROOT/о:LINK/тол:ROOT/к:SUFF/и:END
# 39                                                           кве:ROOT/л:SUFF/ый:END
# 40                                                                    баростат:ROOT
# 41                                                                камб:ROOT/ий:SUFF
# 42                                                            кордебал:ROOT/ет:SUFF
# 43                                                          обыч:ROOT/н:SUFF/ый:END
# 44                                                              женьш:ROOT/ень:SUFF
# 45                                       авто:ROOT/под:PREF/строй:ROOT/к:SUFF/а:END
# 46                                                                       вздох:ROOT
# 47                                               за:PREF/служ:ROOT/ива:SUFF/ть:SUFF
# 48                                              посто:ROOT/я:SUFF/нн:SUFF/ость:SUFF
# 49                                                          сот:ROOT/няг:ROOT/а:END
#
#                                                              Correct segments
# 0                                                     лядун:ROOT/к:SUFF/а:END
# 1                                                              жил:ROOT/а:END
# 2                                   вы:PREF/дых:ROOT/а:SUFF/тельн:SUFF/ый:END
# 3                                      кок:ROOT/а:SUFF/ин:SUFF/ов:SUFF/ый:END
# 4   ради:ROOT/альн:SUFF/о:LINK/-:HYPH/сверл:ROOT/и:SUFF/ль:SUFF/н:SUFF/ый:END
# 5                                                     руб:ROOT/ч:SUFF/ик:SUFF
# 6                                      о:PREF/рог:ROOT/ов:SUFF/е:SUFF/ть:SUFF
# 7                                               сот:ROOT/ен:SUFF/к:SUFF/а:END
# 8                                                        колоратур:ROOT/а:END
# 9                                              подтвержд:ROOT/енн:SUFF/ый:END
# 10                                                    тиран:ROOT/и:SUFF/я:END
# 11                                                           пре:ROOT/ль:SUFF
# 12                            дв:ROOT/у:PREF/лич:ROOT/н:SUFF/ича:SUFF/ть:SUFF
# 13                                                  со:PREF/опек:ROOT/ун:SUFF
# 14                     тез:ROOT/о:SUFF/им:SUFF/ен:SUFF/ит:SUFF/ств:SUFF/о:END
# 15                ча:ROOT/е:LINK/за:PREF/вя:ROOT/л:SUFF/оч:SUFF/н:SUFF/ый:END
# 16                                                     авто:ROOT/реферат:ROOT
# 17                                            гиб:ROOT/ель:SUFF/н:SUFF/ый:END
# 18                                                 намер:ROOT/енн:SUFF/ый:END
# 19                                                  дворц:ROOT/ов:SUFF/ый:END
# 20                                                   бег:ROOT/ун:SUFF/ок:SUFF
# 21                                                     не:PREF/к:ROOT/ого:END
# 22                                                       комби:ROOT/корм:ROOT
# 23                                                      контрибуци:ROOT/я:END
# 24                                                   ботв:ROOT/инь:ROOT/я:END
# 25                                           со:PREF/вмест:ROOT/н:SUFF/ый:END
# 26                              остр:ROOT/о:LINK/сатир:ROOT/ическ:SUFF/ий:END
# 27                          пол:ROOT/у:PREF/не:PREF/завис:ROOT/им:SUFF/ый:END
# 28                                                   полем:ROOT/ик:SUFF/а:END
# 29                                                          плот:ROOT/ик:SUFF
# 30                             с:PREF/толк:ROOT/н:SUFF/ове:SUFF/ни:SUFF/е:END
# 31                                                  пеш:ROOT/оч:SUFF/ком:SUFF
# 32                                                амил:ROOT/нитр:ROOT/ит:SUFF
# 33                                                                крекер:ROOT
# 34                                                 полотн:ROOT/ян:SUFF/ый:END
# 35                                                     под:ROOT/ин:SUFF/а:END
# 36                                            неб:ROOT/о:LINK/с:PREF/вод:ROOT
# 37                                        кон:ROOT/центр:ROOT/ичн:SUFF/ый:END
# 38                                           разн:ROOT/о:LINK/толк:ROOT/и:END
# 39                                                           квел:ROOT/ый:END
# 40                                                  бар:ROOT/о:LINK/стат:ROOT
# 41                                                                камбий:ROOT
# 42                                                      корде:ROOT/балет:ROOT
# 43                                                          обычн:ROOT/ый:END
# 44                                                              женьшень:ROOT
# 45                                      авто:ROOT/под:PREF/строй:ROOT/ка:SUFF
# 46                                                           вз:PREF/дох:ROOT
# 47                                               заслуж:ROOT/ива:SUFF/ть:SUFF
# 48                                                    постоянн:ROOT/ость:SUFF
# 49                                              сот:ROOT/н:SUFF/яг:SUFF/а:END

# %% [markdown]
# ## Get accuracy by number of segments

# %%
max_nb_segments = max([len(c.segments) for p, c in correct] +
                      [len(c.segments) for p, c in wrong])
max_nb_segments
# Out:
# 12

# %%
acc = [0] * 12
for length in range(1, max_nb_segments):
    correct_segments = [c.segments for p, c in correct if len(c.segments) == length]
    wrong_segments = [c.segments for p, c in wrong if len(c.segments) == length]
    
    acc[length] = len(correct_segments) / (len(wrong_segments) + len(correct_segments))

print(acc)
# Out:
# [0, 0.8358686949559647, 0.7747116968698518, 0.8276556776556776, 0.9014179608372721, 0.9277525022747952, 0.8538205980066446, 0.8378378378378378, 0.7647058823529411, 0.7272727272727273, 0.7567567567567568, 0.8]
