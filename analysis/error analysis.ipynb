# %%
import pandas as pd
pd.options.display.max_colwidth = 1000

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('..')

from word2morph import Word2Morph
from word2morph.data.loaders import DataLoader
# Out:
# Using TensorFlow backend.

# %%
word2morph = Word2Morph.load_model(path='../logs/best-model.joblib')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
train = DataLoader(file_path='../datasets/rus.train').load()
valid = DataLoader(file_path='../datasets/rus.valid').load()
test = DataLoader(file_path='../datasets/rus.test').load()

# %%
correct, wrong, predicted_samples = word2morph.evaluate(test, batch_size=1)
# Out:
# Evaluating for epoch 1...
# {'test_acc': 0.9661023800284568,
#  'test_acc_processed': 0.966070042685293,
#  'test_auc': 0.974444504824766,
#  'test_auc_processed': 0.974407395979876,
#  'test_f1': 0.9594611279255,
#  'test_f1_processed': 0.9544572771375242,
#  'test_loss': 1.1707823165168076,
#  'test_loss_processed': 1.1718992087815507,
#  'test_precision': 0.9712482616350767,
#  'test_precision_processed': 0.9596061269102465,
#  'test_recall': 0.9507876769834543,
#  'test_recall_processed': 0.9507148759479704,
#  'test_word_acc': 0.8878060969515242,
#  'test_word_acc_processed': 0.8880143261702482}
# Sample accuracy: 0.8880143261702482

# %%
len(correct), len(wrong), len(predicted_samples)
# Out:
# (21323, 2689, 24012)

# %% [markdown]
# ## Wrong predictions

# %%
# pred, correct
str(wrong[0][0]), str(wrong[0][1])
# Out:
# ('выдыхательный\tвы:PREF/дых:ROOT/а:SUFF/тель:SUFF/н:SUFF/ый:END',
#  'выдыхательный\tвы:PREF/дых:ROOT/а:SUFF/тельн:SUFF/ый:END')

# %%
df = pd.DataFrame(data=[(str(pred).split('\t')[0], str(pred).split('\t')[-1], 
                         str(cor).split('\t')[-1]) for pred, cor in wrong], 
                  columns=['Word', 'Predicted segments', 'Correct segments'])
df.head(n=50)
# Out:
#                Word                                       Predicted segments  \
# 0     выдыхательный          вы:PREF/дых:ROOT/а:SUFF/тель:SUFF/н:SUFF/ый:END
# 1    горько-сладкий               горьк:ROOT/о:LINK/-:HYPH/сладк:ROOT/ий:END
# 2            рубчик                                        руб:ROOT/чик:SUFF
# 3         снетковый                          снет:ROOT/к:SUFF/ов:SUFF/ый:END
# 4         ороговеть                         орог:ROOT/ов:SUFF/е:SUFF/ть:SUFF
# 5           сотенка                                  сот:ROOT/енк:ROOT/а:END
# 6        колоратура                               колорат:ROOT/ур:SUFF/а:END
# 7           тирания                                        тирани:ROOT/я:END
# 8             прель                                               прель:ROOT
# 9      двуличничать                дв:ROOT/у:PREF/лич:ROOT/нича:SUFF/ть:SUFF
# 10         соопекун                                      соопек:ROOT/ун:SUFF
# 11   тезоименитство         тез:ROOT/о:LINK/имен:ROOT/ит:SUFF/ств:SUFF/о:END
# 12          халатик                                             халатик:ROOT
# 13      автореферат                             авто:ROOT/рефер:ROOT/ат:SUFF
# 14        гибельный                                гибель:ROOT/н:SUFF/ый:END
# 15         непрямой                                       непрям:ROOT/ой:END
# 16          ползком                                 пол:ROOT/зк:ROOT/ом:SUFF
# 17           некого                                   не:PREF/ког:ROOT/о:END
# 18        комбикорм                               комб:ROOT/и:ROOT/корм:ROOT
# 19         ботвинья                           ботв:ROOT/ин:SUFF/ь:SUFF/я:END
# 20         полемика                                       полемик:ROOT/а:END
# 21           плотик                                              плотик:ROOT
# 22     столкновение           с:PREF/толк:ROOT/н:SUFF/ов:SUFF/ени:SUFF/е:END
# 23         пешочком                                пеш:ROOT/очк:SUFF/ом:SUFF
# 24       амилнитрит                                    амилнитр:ROOT/ит:SUFF
# 25           крекер                                        крек:ROOT/ер:SUFF
# 26       полотняный                         полот:ROOT/н:SUFF/ян:SUFF/ый:END
# 27     бродяжничать                брод:ROOT/яж:ROOT/нич:SUFF/а:SUFF/ть:SUFF
# 28           квелый                                   кве:ROOT/л:SUFF/ый:END
# 29         баростат                                            баростат:ROOT
# 30           камбий                                        камб:ROOT/ий:SUFF
# 31       кордебалет                                          кордебалет:ROOT
# 32          обычный                                  обыч:ROOT/н:SUFF/ый:END
# 33   автоподстройка               авто:ROOT/под:PREF/строй:ROOT/к:SUFF/а:END
# 34           раввин                                        равв:ROOT/ин:SUFF
# 35       добренький                         до:PREF/бр:ROOT/еньк:SUFF/ий:END
# 36     постоянность                по:PREF/сто:ROOT/я:SUFF/нн:SUFF/ость:SUFF
# 37          сотняга                                        сотняг:ROOT/а:END
# 38           форзац                                        форз:ROOT/ац:SUFF
# 39         аневризм                                      аневр:ROOT/изм:SUFF
# 40   диакритический                     диакрит:ROOT/ич:SUFF/еск:SUFF/ий:END
# 41   скачкообразный               скачк:ROOT/о:LINK/образ:ROOT/н:SUFF/ый:END
# 42       уступчатый                         уступ:ROOT/ч:SUFF/ат:SUFF/ый:END
# 43           вышина                                   вы:PREF/шин:ROOT/а:END
# 44      старушенция                        старуш:ROOT/енц:ROOT/и:SUFF/я:END
# 45      капельдинер                                   капельдин:ROOT/ер:SUFF
# 46  тароупаковочный  тар:ROOT/о:LINK/у:PREF/паков:ROOT/оч:SUFF/н:SUFF/ый:END
# 47     зодиакальный                                   зодиакальн:ROOT/ый:END
# 48         казначей                                            казначей:ROOT
# 49          сидячий                                 сид:ROOT/яч:SUFF/ий:SUFF
#
#                                                  Correct segments
# 0                       вы:PREF/дых:ROOT/а:SUFF/тельн:SUFF/ый:END
# 1                горьк:ROOT/о:LINK/-:HYPH/слад:ROOT/к:SUFF/ий:END
# 2                                         руб:ROOT/ч:SUFF/ик:SUFF
# 3                                       снетк:ROOT/ов:SUFF/ый:END
# 4                          о:PREF/рог:ROOT/ов:SUFF/е:SUFF/ть:SUFF
# 5                                   сот:ROOT/ен:SUFF/к:SUFF/а:END
# 6                                            колоратур:ROOT/а:END
# 7                                         тиран:ROOT/и:SUFF/я:END
# 8                                                пре:ROOT/ль:SUFF
# 9                 дв:ROOT/у:PREF/лич:ROOT/н:SUFF/ича:SUFF/ть:SUFF
# 10                                      со:PREF/опек:ROOT/ун:SUFF
# 11         тез:ROOT/о:SUFF/им:SUFF/ен:SUFF/ит:SUFF/ств:SUFF/о:END
# 12                                             халат:ROOT/ик:SUFF
# 13                                         авто:ROOT/реферат:ROOT
# 14                                гиб:ROOT/ель:SUFF/н:SUFF/ый:END
# 15                                       не:PREF/прям:ROOT/ой:END
# 16                                       полз:ROOT/к:SUFF/ом:SUFF
# 17                                         не:PREF/к:ROOT/ого:END
# 18                                           комби:ROOT/корм:ROOT
# 19                                       ботв:ROOT/инь:ROOT/я:END
# 20                                       полем:ROOT/ик:SUFF/а:END
# 21                                              плот:ROOT/ик:SUFF
# 22                 с:PREF/толк:ROOT/н:SUFF/ове:SUFF/ни:SUFF/е:END
# 23                                      пеш:ROOT/оч:SUFF/ком:SUFF
# 24                                    амил:ROOT/нитр:ROOT/ит:SUFF
# 25                                                    крекер:ROOT
# 26                                     полотн:ROOT/ян:SUFF/ый:END
# 27                            брод:ROOT/яж:ROOT/нича:SUFF/ть:SUFF
# 28                                               квел:ROOT/ый:END
# 29                                      бар:ROOT/о:LINK/стат:ROOT
# 30                                                    камбий:ROOT
# 31                                          корде:ROOT/балет:ROOT
# 32                                              обычн:ROOT/ый:END
# 33                          авто:ROOT/под:PREF/строй:ROOT/ка:SUFF
# 34                                                    раввин:ROOT
# 35                                     добр:ROOT/еньк:SUFF/ий:END
# 36                                        постоянн:ROOT/ость:SUFF
# 37                                  сот:ROOT/н:SUFF/яг:SUFF/а:END
# 38                                                    форзац:ROOT
# 39                                      а:PREF/невр:ROOT/изм:SUFF
# 40                                 диакритич:ROOT/еск:SUFF/ий:END
# 41               скач:ROOT/к:SUFF/о:LINK/образ:ROOT/н:SUFF/ый:END
# 42                                     уступ:ROOT/чат:SUFF/ый:END
# 43                                         выш:ROOT/ин:SUFF/а:END
# 44                              стар:ROOT/уш:SUFF/енци:SUFF/я:END
# 45                                               капельдинер:ROOT
# 46  тар:ROOT/о:LINK/у:PREF/пак:ROOT/ов:SUFF/оч:SUFF/н:SUFF/ый:END
# 47                                   зодиак:ROOT/альн:SUFF/ый:END
# 48                                            казн:ROOT/ачей:SUFF
# 49                                        сид:ROOT/яч:SUFF/ий:END

# %% [markdown]
# ## Get accuracy by number of segments

# %%
max_nb_segments = max([len(c.segments) for p, c in correct] +
                      [len(c.segments) for p, c in wrong])
max_nb_segments
# Out:
# 12

# %%
acc = [0] * (max_nb_segments + 1)
nb_words = [0] * (max_nb_segments + 1)
for length in range(1, max_nb_segments + 1):
    correct_segments = [c.segments for p, c in correct if len(c.segments) == length]
    wrong_segments = [c.segments for p, c in wrong if len(c.segments) == length]
    
    acc[length] = len(correct_segments) / (len(wrong_segments) + len(correct_segments))
    nb_words[length] = sum([1 for p, c in correct if len(c.segments) == length]) + \
                       sum([1 for p, c in wrong if len(c.segments) == length])

d = pd.DataFrame(data=zip(acc, nb_words), columns=['ACC', '#words'])
d.head(n=50)
# Out:
#          ACC  #words
# 0   0.000000       0
# 1   0.847078    1249
# 2   0.792010    2428
# 3   0.855678    5460
# 4   0.921540    7405
# 5   0.935396    5495
# 6   0.870432    1204
# 7   0.877339     481
# 8   0.847059     170
# 9   0.779221      77
# 10  0.756757      37
# 11  0.800000       5
# 12  0.000000       1
