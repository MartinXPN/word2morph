# %%
from collections import Counter
import operator

import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('..')
from src.entities.dataset import BucketDataset, Dataset
from src.data.loaders import DataLoader

# %%
def show_dataset_statistics(dataset: Dataset):
    print('Dataset size:', len(dataset))
    for sample in dataset[:10]:
        print(sample)
    
    f, ax = plt.subplots(ncols=4)
    f.set_figheight(3)
    f.set_figwidth(20)
    f.dpi = 150
    
    # Word lengths
    n, bins, patches = ax[0].hist(x=[len(sample.word) for sample in dataset], bins=50, facecolor='b')
    ax[0].set_xlabel('Word lengths')
    ax[0].set_ylabel('Counts')
    
    # Number of segments for each word 
    n, bins, patches = ax[1].hist(x=[len(sample.segments) for sample in dataset], bins=30, facecolor='r')
    ax[1].set_xlabel('Number of segments for each word')
    ax[1].set_ylabel('Counts')
    
    
    # Occurances of word segment parts
    segments = Counter([seg for sample in dataset for seg in sample.segment_parts])
    sorted_segments = sorted(segments.items(), key=operator.itemgetter(1))[::-1]

    ax[2].scatter(x=list(range(len(segments))), y=[seg[1] for seg in sorted_segments])
    ax[2].set_xlabel('Occurances of word segment parts')
    ax[2].set_ylabel('Counts')

    print('Top segments')
    print(sorted_segments[:10])
    
    n, bins, patches = ax[3].hist(x=[len(seg) for sample in dataset for seg in sample.segment_parts], bins=15, facecolor='y')
    ax[3].set_xlabel('Number of segments for each word')
    ax[3].set_ylabel('Counts')
    
    plt.show()

# %%
show_dataset_statistics(dataset=Dataset(samples=DataLoader(file_path='../datasets/rus.train').load()))
# Out:
# Dataset size: 72034
# одуматься -> ((о:PREF), (дум:ROOT), (а:SUFF), (ть:SUFF), (ся:POSTFIX))
# врать -> ((вр:ROOT), (а:SUFF), (ть:SUFF))
# хлюстовой -> ((хлюст:ROOT), (ов:SUFF), (ой:END))
# отклеить -> ((от:PREF), (кле:ROOT), (и:SUFF), (ть:SUFF))
# писание -> ((пис:ROOT), (а:SUFF), (ни:SUFF), (е:END))
# продрогнуть -> ((про:PREF), (дрог:ROOT), (ну:SUFF), (ть:SUFF))
# переключить -> ((пере:PREF), (ключ:ROOT), (и:SUFF), (ть:SUFF))
# зашпунтовываться -> ((за:PREF), (шпунт:ROOT), (ов:SUFF), (ыва:SUFF), (ть:SUFF), (ся:POSTFIX))
# смотать -> ((с:PREF), (мот:ROOT), (а:SUFF), (ть:SUFF))
# экспедиция -> ((экспед:ROOT), (ици:SUFF), (я:END))
# Top segments
# [('ть', 19323), ('ый', 16549), ('а', 13763), ('о', 12275), ('н', 8046), ('и', 7961), ('ся', 7675), ('е', 5739), ('ий', 5327), ('к', 3596)]

# %%
show_dataset_statistics(dataset=Dataset(samples=DataLoader(file_path='../datasets/eng.train').load()))
# Out:
# Dataset size: 1000
# ablatives -> ((ablative:None), (s:None))
# abounded -> ((abound:None), (ed:None))
# abrogate -> ((abrogate:None))
# abusing -> ((ab:None), (us:None), (ing:None))
# accents' -> ((accent:None), (s:None), (':None))
# accorded -> ((accord:None), (ed:None))
# actions -> ((act:None), (ion:None), (s:None))
# actress' -> ((act:None), (r:None), (ess:None), (':None))
# adder's -> ((adder:None), ('s:None))
# adultery -> ((adult:None), (ery:None))
# Top segments
# [('s', 285), ("'s", 118), ('ing', 77), ('ed', 77), ("'", 68), ('er', 60), ('-', 36), ('es', 29), ('ion', 22), ('ly', 21)]

# %%
show_dataset_statistics(dataset=Dataset(samples=DataLoader(file_path='../datasets/fin.train').load()))
# Out:
# Dataset size: 1000
# aatteilla -> ((aatte:None), (i:None), (lla:None))
# adoptioilta -> ((adoptio:None), (i:None), (lta:None))
# adoptiotyttärensä -> ((adoptio:None), (tyttäre:None), (nsä:None))
# afaatikoilla -> ((afaatiko:None), (i:None), (lla:None))
# ahdistetun -> ((ahdiste:None), (tu:None), (n:None))
# aikuisväestöstä -> ((aikuis:None), (väestö:None), (stä:None))
# ainekseltaan -> ((ainekse:None), (lta:None), (an:None))
# ainuttakaan -> ((ainut:None), (ta:None), (kaan:None))
# ajoilta -> ((ajo:None), (i:None), (lta:None))
# ajojen -> ((ajo:None), (j:None), (en:None))
# Top segments
# [('i', 232), ('n', 187), ('a', 95), ('t', 79), ('sta', 63), ('en', 55), ('j', 49), ('lla', 42), ('ssa', 41), ('u', 38)]

# %%
show_dataset_statistics(dataset=Dataset(samples=DataLoader(file_path='../datasets/tur.train').load()))
# Out:
# Dataset size: 1000
# CIkarsanIz -> ((CIk:None), (ar:None), (sa:None), (nIz:None))
# CIkmazIna -> ((CIkmaz:None), (I:None), (na:None))
# COlU -> ((COl:None), (U:None))
# COmleGi -> ((COmleG:None), (i:None))
# COplUGUnde -> ((COp:None), (lUG:None), (U:None), (nde:None))
# COzUmU -> ((COz:None), (Um:None), (U:None))
# CaGan -> ((CaGa:None), (n:None))
# CaGlIyorlar -> ((CaG:None), (lIyor:None), (lar:None))
# CaGlayanlarI -> ((CaG:None), (la:None), (yan:None), (lar:None), (I:None))
# CabalarImIn -> ((Caba:None), (lar:None), (Im:None), (In:None))
# Top segments
# [('ler', 116), ('i', 108), ('lar', 102), ('I', 82), ('ma', 65), ('me', 53), ('in', 52), ('In', 52), ('dir', 42), ('la', 40)]
